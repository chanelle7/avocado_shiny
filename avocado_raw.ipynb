# %%
import numpy as np
import pandas as pd

pd.set_option('display.float_format', lambda x: '%.2f' % x)

avocado = pd.read_csv('avocado.csv')
avocado = avocado.iloc[:,1:]
avocado.Date = pd.to_datetime(avocado.Date)

avocado.sample(10)
# Out:
#             Date  AveragePrice  Total Volume      4046       4225     4770  \
# 13435 2016-02-07          1.95      30482.41   4811.67    9963.04  1515.57
# 13194 2016-09-25          1.43       1041.31     16.55      20.32     0.00
# 9534  2015-02-22          1.90       3180.29    198.13    1119.06   992.87
# 17169 2017-03-05          0.99     155011.12  35367.23    5175.81     5.91
# 2846  2016-04-03          0.85      81694.23    676.27   70459.66    31.20
# 6971  2017-06-04          1.43    3212276.31 699461.68 1357927.08 31609.48
# 12031 2016-02-07          1.72       5420.87   1932.23    2613.21     0.00
# 14530 2016-01-17          1.53       1478.04      6.25     226.16     0.00
# 5617  2017-12-24          1.45      77039.09   2811.71   58592.23    19.06
# 7605  2017-06-18          1.34     263858.47  63136.38   95583.32  6670.12
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
avocado.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %%
avocado['Total Volume'] = avocado['Total Volume'].round(0)
avocado['4046']=avocado['4046'].round(0)
avocado['4225']=avocado['4225'].round(0)
avocado['4770']=avocado['4770'].round(0)
avocado['Total Bags']=avocado['Total Bags'].round(0)
avocado['Small Bags']=avocado['Small Bags'].round(0)
avocado['Large Bags']=avocado['Large Bags'].round(0)
avocado['XLarge Bags']=avocado['XLarge Bags'].round(0)
avocado.sample(4)
# Out:
#             Date  AveragePrice  Total Volume      4046       4225     4770  \
# 17821 2018-02-25          1.41      25591.00   5721.00      69.00     0.00
# 7241  2017-04-30          1.39     407790.00   9127.00  296828.00  1940.00
# 7178  2017-07-09          1.58    4406342.00 289590.00 2850917.00 25597.00
# 9637  2015-03-01          1.24      10963.00    271.00    9758.00     0.00
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 17821    19801.00    19544.00      257.00         0.00       organic  2018
# 7241     99896.00    41352.00    58543.00         0.00  conventional  2017
# 7178   1240236.00  1034139.00   140036.00     66062.00  conventional  2017
# 9637       934.00      697.00      237.00         0.00       organic  2015
#
#                    region
# 17821             Houston
# 7241   NorthernNewEngland
# 7178            Northeast
# 9637     CincinnatiDayton

# %%
avocado.describe()
# Out:
#        AveragePrice  Total Volume        4046        4225       4770  \
# count      18249.00      18249.00    18249.00    18249.00   18249.00
# mean           1.41     850644.01   293008.42   295154.57   22839.74
# std            0.40    3453545.36  1264989.08  1204120.41  107464.07
# min            0.44         85.00        0.00        0.00       0.00
# 25%            1.10      10839.00      854.00     3009.00       0.00
# 50%            1.37     107377.00     8645.00    29061.00     185.00
# 75%            1.66     432962.00   111020.00   150207.00    6243.00
# max            3.25   62505647.00 22743616.00 20470573.00 2546439.00
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     year
# count    18249.00    18249.00    18249.00     18249.00 18249.00
# mean    239639.20   182194.69    54338.09      3106.43  2016.15
# std     986242.40   746178.52   243965.96     17692.90     0.94
# min          0.00        0.00        0.00         0.00  2015.00
# ...

# %%
avocado['test_volume'] = avocado['4046']+avocado['4225']+avocado['4770']

# %%
avocado['missing_volume'] = avocado['Total Volume'] - avocado['test_volume']

# %%
avocado[['Total Volume','test_volume','missing_volume','4046','4225','4770']]
# Out:
#        Total Volume  test_volume  missing_volume      4046      4225    4770
# 0          64237.00     55540.00         8697.00   1037.00  54455.00   48.00
# 1          54877.00     45371.00         9506.00    674.00  44639.00   58.00
# 2         118220.00    110075.00         8145.00    795.00 109150.00  130.00
# 3          78992.00     73181.00         5811.00   1132.00  71976.00   73.00
# 4          51040.00     44855.00         6185.00    941.00  43838.00   76.00
# 5          55980.00     49296.00         6684.00   1184.00  48068.00   44.00
# 6          83454.00     75135.00         8319.00   1369.00  73673.00   93.00
# 7         109428.00    102599.00         6829.00    704.00 101815.00   80.00
# 8          99811.00     88423.00        11388.00   1022.00  87316.00   85.00
# 9          74339.00     65712.00         8627.00    842.00  64757.00  113.00
# 10         84843.00     76638.00         8205.00    925.00  75596.00  117.00
# ...

# %% [markdown]
# there are other PLU codes for other varieties of avocados hence the missing data.
#
# 4046 are small avocados
# 4225 are medium sized avocados
# 4770 are large avocados
#
# http://www.bobbywires.com/plu-1.php?S=P&L=A&V=AVOCADOS
#
# the total avocados are for individual avocados just like plu tags are for single avocados sold in that week

# %%
avocado['bag_test'] = avocado['Small Bags'] + avocado['Large Bags'] + avocado['XLarge Bags']
avocado['missing_bag'] = avocado['Total Bags'] - avocado['bag_test']

# %%
avocado[['Total Bags', 'bag_test','missing_bag','Small Bags','Large Bags','XLarge Bags']]
# Out:
#        Total Bags   bag_test  missing_bag  Small Bags  Large Bags  XLarge Bags
# 0         8697.00    8697.00         0.00     8604.00       93.00         0.00
# 1         9506.00    9505.00         1.00     9408.00       97.00         0.00
# 2         8145.00    8145.00         0.00     8042.00      103.00         0.00
# 3         5811.00    5811.00         0.00     5677.00      134.00         0.00
# 4         6184.00    6184.00         0.00     5986.00      198.00         0.00
# 5         6684.00    6683.00         1.00     6556.00      127.00         0.00
# 6         8319.00    8319.00         0.00     8197.00      122.00         0.00
# 7         6829.00    6829.00         0.00     6267.00      562.00         0.00
# 8        11388.00   11389.00        -1.00    11105.00      284.00         0.00
# 9         8626.00    8625.00         1.00     8061.00      564.00         0.00
# 10        8206.00    8206.00         0.00     7878.00      328.00         0.00
# ...

# %% [markdown]
# no missing info in bags sold, all the bags add up to total bags

# %%
avocado.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region', 'test_volume', 'missing_volume', 'bag_test', 'missing_bag'],
#       dtype='object')

# %%
avocado.rename(columns={'AveragePrice':'Avg_Price',
                       'Total Volume':'Total_Volume',
                       '4046':'Small_4046',
                       '4225':'Medium_4225',
                       '4770':'Large_4770',
                       'missing_volume':'Other_PLU',
                       'bag_test':'Total_Bags',
                       'Small Bags':'Small_Bags',
                       'Large Bags':'Medium_Bags',
                       'XLarge Bags':'Large_Bags',
                       'type':'Type',
                       'year':'Year',
                       'region':'Region'},
              inplace=True)

# %%
avocado.sample(10)
# Out:
#             Date  Avg_Price  Total_Volume  Small_4046  Medium_4225  \
# 9737  2015-03-29       1.36       9162.00     6161.00       468.00
# 9503  2015-09-27       2.16       2966.00      292.00      1201.00
# 12145 2016-11-27       1.94       9786.00       30.00       908.00
# 16163 2017-02-26       0.68      10921.00      330.00      2415.00
# 5718  2017-01-22       0.84     755472.00   320378.00    135921.00
# 15587 2017-01-08       1.55     100135.00     4238.00     57605.00
# 4889  2016-12-18       1.04     384448.00   125324.00    218206.00
# 7692  2017-10-29       1.30     143343.00    36193.00     35008.00
# 6242  2017-03-05       0.93    1105083.00   558907.00    208324.00
# 2067  2015-03-29       1.13     117662.00    46540.00     46916.00
#
#        Large_4770  Total Bags  Small_Bags  Medium_Bags  Large_Bags  \
# 9737         0.00     2533.00     2533.00         0.00        0.00
# 9503       867.00      606.00      606.00         0.00        0.00
# ...

# %%
avocado2 = avocado[['Date','Year','Avg_Price','Total_Volume',
                   'Small_4046','Medium_4225','Large_4770','Other_PLU',
                   'Total_Bags','Small_Bags','Medium_Bags','Large_Bags',
                   'Type','Region']]

# %%
avocado2.sample(10)
# Out:
#             Date  Year  Avg_Price  Total_Volume  Small_4046  Medium_4225  \
# 10434 2015-11-01  2015       1.61      54907.00     5464.00     26551.00
# 14682 2016-02-14  2016       1.07     292308.00    27729.00     74888.00
# 10811 2015-08-02  2015       1.94       5148.00      369.00      1877.00
# 11647 2015-07-05  2015       1.86       4129.00     2030.00      1665.00
# 12851 2016-05-01  2016       2.40      13841.00      105.00      6947.00
# 11628 2015-11-15  2015       1.25       5713.00     1627.00      1241.00
# 1270  2015-07-26  2015       1.24     379954.00   233057.00     63066.00
# 16906 2017-02-19  2017       2.32       5376.00     1718.00      3243.00
# 17473 2017-06-11  2017       1.56    1397448.00   160842.00    339777.00
# 9142  2015-09-06  2015       1.86       1169.00       30.00        96.00
#
#        Large_4770  Other_PLU  Total_Bags  Small_Bags  Medium_Bags  Large_Bags  \
# 10434     3799.00   19093.00    19093.00    12312.00      6781.00        0.00
# ...

# %%
avocado2.Type.value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: Type, dtype: int64

# %%
avocado2.Region.value_counts()
# Out:
# HartfordSpringfield    338
# Orlando                338
# NewYork                338
# Chicago                338
# SanFrancisco           338
# Denver                 338
# BuffaloRochester       338
# Atlanta                338
# Charlotte              338
# SanDiego               338
# BaltimoreWashington    338
# LosAngeles             338
# Syracuse               338
# Detroit                338
# Jacksonville           338
# Tampa                  338
# NorthernNewEngland     338
# CincinnatiDayton       338
# HarrisburgScranton     338
# Philadelphia           338
# Boston                 338
# Midsouth               338
# Nashville              338
# West                   338
# Albany                 338
# Southeast              338
# GreatLakes             338
# Northeast              338
# Roanoke                338
# TotalUS                338
# Boise                  338
# Plains                 338
# Sacramento             338
# Indianapolis           338
# ...

# %%
avocado2.dtypes
# Out:
# Date            datetime64[ns]
# Year                     int64
# Avg_Price              float64
# Total_Volume           float64
# Small_4046             float64
# Medium_4225            float64
# Large_4770             float64
# Other_PLU              float64
# Total_Bags             float64
# Small_Bags             float64
# Medium_Bags            float64
# Large_Bags             float64
# Type                    object
# Region                  object
# dtype: object

# %%
avocado2 = avocado2.astype({'Total_Volume':'int64',
                'Small_4046':'int64',
                'Medium_4225':'int64',
                'Large_4770':'int64',
                'Other_PLU':'int64',
                'Total_Bags':'int64',
                'Small_Bags':'int64',
                'Medium_Bags':'int64',
                'Large_Bags':'int64'})

# %%
avocado2.min()
avocado2.max()
# Out:
# Date            2015-01-04 00:00:00
# Year                           2015
# Avg_Price                      0.44
# Total_Volume                     85
# Small_4046                        0
# Medium_4225                       0
# Large_4770                        0
# Other_PLU                        -1
# Total_Bags                        0
# Small_Bags                        0
# Medium_Bags                       0
# Large_Bags                        0
# Type                   conventional
# Region                       Albany
# dtype: object
# Date            2018-03-25 00:00:00
# Year                           2018
# Avg_Price                      3.25
# Total_Volume               62505647
# Small_4046                 22743616
# Medium_4225                20470573
# Large_4770                  2546439
# Other_PLU                  19373135
# Total_Bags                 19373135
# Small_Bags                 13384587
# Medium_Bags                 5719097
# ...

# %%
#check up negative plu values

avocado2[avocado2.Other_PLU<0]
# Out:
#             Date  Year  Avg_Price  Total_Volume  Small_4046  Medium_4225  \
# 9212  2015-05-03  2015       2.03          3976        1326         2651
# 11320 2015-10-18  2015       2.79         12642         962        11681
# 11347 2015-04-12  2015       1.54         28220       18888         9333
# 11594 2015-07-12  2015       2.07          2786         681         2106
# 11595 2015-07-05  2015       1.85          3162         800         2363
# 11596 2015-06-28  2015       1.61          4088         538         3551
#
#        Large_4770  Other_PLU  Total_Bags  Small_Bags  Medium_Bags  Large_Bags  \
# 9212            0         -1           0           0            0           0
# 11320           0         -1           0           0            0           0
# 11347           0         -1           0           0            0           0
# 11594           0         -1           0           0            0           0
# ...

# %%
index_change = [9212,11320,11347,11594,11595,11596]

for i in index_change:
    if avocado2.iloc[i,7]==-1:
        avocado2.iloc[i,7]=0
    print(avocado2.iloc[i,7])
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %%
#addition tests

avocado2[avocado2.Total_Volume != (avocado2.Small_4046 + avocado2.Medium_4225 + avocado2.Large_4770 + avocado2.Other_PLU)]
# Out:
#             Date  Year  Avg_Price  Total_Volume  Small_4046  Medium_4225  \
# 9212  2015-05-03  2015       2.03          3976        1326         2651
# 11320 2015-10-18  2015       2.79         12642         962        11681
# 11347 2015-04-12  2015       1.54         28220       18888         9333
# 11594 2015-07-12  2015       2.07          2786         681         2106
# 11595 2015-07-05  2015       1.85          3162         800         2363
# 11596 2015-06-28  2015       1.61          4088         538         3551
#
#        Large_4770  Other_PLU  Total_Bags  Small_Bags  Medium_Bags  Large_Bags  \
# 9212            0          0           0           0            0           0
# 11320           0          0           0           0            0           0
# 11347           0          0           0           0            0           0
# 11594           0          0           0           0            0           0
# ...

# %%
avocado2[avocado2.Total_Bags != (avocado2.Small_Bags+avocado2.Medium_Bags+avocado2.Large_Bags)]
# Out:
# Empty DataFrame
# Columns: [Date, Year, Avg_Price, Total_Volume, Small_4046, Medium_4225, Large_4770, Other_PLU, Total_Bags, Small_Bags, Medium_Bags, Large_Bags, Type, Region]
# Index: []

# %%
avocado2.isnull().sum()
# Out:
# Date            0
# Year            0
# Avg_Price       0
# Total_Volume    0
# Small_4046      0
# Medium_4225     0
# Large_4770      0
# Other_PLU       0
# Total_Bags      0
# Small_Bags      0
# Medium_Bags     0
# Large_Bags      0
# Type            0
# Region          0
# dtype: int64

# %%
avocado2[(avocado2.Date == '2017-05-14') & (avocado2.Region=='Albany')]
# Out:
#             Date  Year  Avg_Price  Total_Volume  Small_4046  Medium_4225  \
# 5649  2017-05-14  2017       1.77         96751        2805        80469
# 14774 2017-05-14  2017       1.57          4270          44          451
#
#        Large_4770  Other_PLU  Total_Bags  Small_Bags  Medium_Bags  Large_Bags  \
# 5649          196      13281       13280        5728         7552           0
# 14774           0       3775        3775        3775            0           0
#
#                Type  Region
# 5649   conventional  Albany
# 14774       organic  Albany

# %%
avocado2.Region.value_counts().count()
# Out:
# 54

# %%
# avocado2.to_csv('avocado_cleaned.csv',index=False)

# %%
avocado2.columns
# Out:
# Index(['Date', 'Year', 'Avg_Price', 'Total_Volume', 'Small_4046',
#        'Medium_4225', 'Large_4770', 'Other_PLU', 'Total_Bags', 'Small_Bags',
#        'Medium_Bags', 'Large_Bags', 'Type', 'Region'],
#       dtype='object')

# %%
from pprint import pprint as pp

# %%
pp(avocado2.columns)
# Out:
# Index(['Date', 'Year', 'Avg_Price', 'Total_Volume', 'Small_4046',
#        'Medium_4225', 'Large_4770', 'Other_PLU', 'Total_Bags', 'Small_Bags',
#        'Medium_Bags', 'Large_Bags', 'Type', 'Region'],
#       dtype='object')

# %%
avocado2.Region.value_counts()
# Out:
# HartfordSpringfield    338
# Orlando                338
# NewYork                338
# Chicago                338
# SanFrancisco           338
# Denver                 338
# BuffaloRochester       338
# Atlanta                338
# Charlotte              338
# SanDiego               338
# BaltimoreWashington    338
# LosAngeles             338
# Syracuse               338
# Detroit                338
# Jacksonville           338
# Tampa                  338
# NorthernNewEngland     338
# CincinnatiDayton       338
# HarrisburgScranton     338
# Philadelphia           338
# Boston                 338
# Midsouth               338
# Nashville              338
# West                   338
# Albany                 338
# Southeast              338
# GreatLakes             338
# Northeast              338
# Roanoke                338
# TotalUS                338
# Boise                  338
# Plains                 338
# Sacramento             338
# Indianapolis           338
# ...

# %% [markdown]
# must separate df into separate df for cities, regions, and whole USA

# %%
USA_avocado = avocado2[avocado2.Region == 'TotalUS']

# %%
avocado2.Region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
areas = ['GreatLakes',
         'Midsouth',
         'Northeast',
         'NorthernNewEngland',
         'SouthCentral',
         'Southeast',
         'West',
        'Plains',
        'California']

areas2 = ['GreatLakes',
         'Midsouth',
         'Northeast',
         'SouthCentral',
         'Southeast',
         'West',
        'Plains']

rest_of_country=[]
for i in avocado2.Region.unique():
    if (i not in areas) & (i != 'TotalUS'):
        rest_of_country.append(i)

# %%
vol_bag_by_region = avocado2.groupby('Region').sum().sort_values(by='Total_Volume', ascending=False)[['Total_Volume','Total_Bags']]

# %%
vol_bag_by_region
# Out:
#                      Total_Volume  Total_Bags
# Region
# TotalUS                5864740188  1638600778
# West                   1086779150   367073629
# California             1028981653   246682214
# SouthCentral           1011279624   233392415
# Northeast               713280910   196988391
# Southeast               615238417   181527646
# GreatLakes              589642535   178575661
# Midsouth                508349347   156513626
# LosAngeles              507896557   168264529
# Plains                  311188526    77847196
# NewYork                 240734129    67994164
# DallasFtWorth           208419290    46469737
# Houston                 203167878    50215057
# PhoenixTucson           195643311    38908250
# WestTexNewMexico        144521841    35296515
# Denver                  138902538    58957013
# SanFrancisco            135830190    14890908
# BaltimoreWashington     134713923    35306149
# Chicago                 133702328    16865396
# ...

# %%
vol_bag_by_region.loc[areas,].sum()[0]-vol_bag_by_region.loc[['TotalUS'],].sum()[0]
vol_bag_by_region.loc[areas,].sum()[1]-vol_bag_by_region.loc[['TotalUS'],].sum()[1]
# Out:
# 71532870
# 13905028

# %%
vol_bag_by_region.loc[areas2,].sum()[0]-vol_bag_by_region.loc[['TotalUS'],].sum()[0]
vol_bag_by_region.loc[areas2,].sum()[1]-vol_bag_by_region.loc[['TotalUS'],].sum()[1]
# Out:
# -1028981679
# -246682214

# %%
vol_bag_by_region.loc[rest_of_country,].sum()[0]-5864740188
# Out:
# -2142350857

# %%
vol_bag_by_region.loc[['LosAngeles','SanFrancisco','SanDiego','Sacramento'],].sum()[0]-vol_bag_by_region.loc[['California'],].sum()[0]
# Out:
# -220299237

# %%
vol_bag_by_region.loc[['LosAngeles','SanFrancisco','SanDiego','Sacramento'],].sum()[1]-vol_bag_by_region.loc[['California'],].sum()[1]
# Out:
# -31201833

# %%
vol_bag_by_region.loc[['BuffaloRochester','Albany','Syracuse'],].sum()[0]-\
vol_bag_by_region.loc[['NewYork'],].sum()[0]
# Out:
# -190761200

# %%
remove_regions = ['GreatLakes',
                 'Midsouth',
                 'Northeast',
                 'NorthernNewEngland',
                 'SouthCentral',
                 'Southeast',
                 'West',
                'Plains',
                'California',
                 'TotalUS']
avocado3 = avocado2[~avocado2.Region.isin(remove_regions)]

# %%
avocado3.head(10)
# Out:
#         Date  Year  Avg_Price  Total_Volume  Small_4046  Medium_4225  \
# 0 2015-12-27  2015       1.33         64237        1037        54455
# 1 2015-12-20  2015       1.35         54877         674        44639
# 2 2015-12-13  2015       0.93        118220         795       109150
# 3 2015-12-06  2015       1.08         78992        1132        71976
# 4 2015-11-29  2015       1.28         51040         941        43838
# 5 2015-11-22  2015       1.26         55980        1184        48068
# 6 2015-11-15  2015       0.99         83454        1369        73673
# 7 2015-11-08  2015       0.98        109428         704       101815
# 8 2015-11-01  2015       1.02         99811        1022        87316
# 9 2015-10-25  2015       1.07         74339         842        64757
#
#    Large_4770  Other_PLU  Total_Bags  Small_Bags  Medium_Bags  Large_Bags  \
# 0          48       8697        8697        8604           93           0
# ...

# %%
# avocado3.to_csv('city_avocado.csv', )

# %%
avocado3.Region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'Charlotte', 'Chicago', 'CincinnatiDayton',
#        'Columbus', 'DallasFtWorth', 'Denver', 'Detroit', 'GrandRapids',
#        'HarrisburgScranton', 'HartfordSpringfield', 'Houston',
#        'Indianapolis', 'Jacksonville', 'LasVegas', 'LosAngeles',
#        'Louisville', 'MiamiFtLauderdale', 'Nashville', 'NewOrleansMobile',
#        'NewYork', 'Orlando', 'Philadelphia', 'PhoenixTucson',
#        'Pittsburgh', 'Portland', 'RaleighGreensboro', 'RichmondNorfolk',
#        'Roanoke', 'Sacramento', 'SanDiego', 'SanFrancisco', 'Seattle',
#        'SouthCarolina', 'Spokane', 'StLouis', 'Syracuse', 'Tampa',
#        'WestTexNewMexico'], dtype=object)

# %%
location_dict = {
    'Albany':[42.652580, -73.756233],
    'Atlanta':[33.748997, -84.387985],
    'Baltimore':[39.290386,-76.612190]
}

# %%
location_dict
# Out:
# {'Albany': [42.65258, -73.756233]}
